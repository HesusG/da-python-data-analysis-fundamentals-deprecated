# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
vida = pd.read_csv('vida.csv')

# %%
vida2 = vida.dropna(how='any')

# %%
plt = vida2.drop(['Country Name'], axis=1)
plt = plt.set_index('Country Code').transpose()
plt.iloc[:,1:10].plot()

# %%
plt = vida2.drop(['Country Name'], axis=1)
plt = plt.set_index('Country Code').transpose()
plt.iloc[:,1:10].plot(kind='box')

# %% [markdown]
# # Créditos

# %%
credit = pd.read_csv('CasoCreditos.csv')

# %%
credit.head()
# Out:
#       loan_id status    due_date   paid_date  loan_amount  risk_score  gender  \
# 0  bb08b55c1f   loan  2018-06-02         NaN         1900       0.133   Mujer
# 1  f23fd22961   paid  2018-06-01  2018-05-29         2400       0.941   Mujer
# 2  b723773be8   paid  2018-06-01  2018-05-21         1900       0.945   Mujer
# 3  726c7712e0   paid  2018-06-01  2018-04-02         2000       0.905   Mujer
# 4  8151753f45   paid  2018-06-01  2018-05-29         1600       0.908  Hombre
#
#    age  dependants   device urban_city loan_usage
# 0   33           0  android      rural      Otros
# 1   41           2      ios     urbano  Educacion
# 2   45           0      ios     urbano  Educacion
# 3   18           0      ios      rural  Educacion
# 4   18           0      ios     urbano  Educacion

# %%
credit.corr()
# Out:
#              loan_amount  risk_score       age  dependants
# loan_amount     1.000000    0.016775  0.013699    0.004704
# risk_score      0.016775    1.000000  0.061914    0.017301
# age             0.013699    0.061914  1.000000   -0.006916
# dependants      0.004704    0.017301 -0.006916    1.000000

# %%
data = credit.copy()
data.head()
# Out:
#       loan_id status    due_date   paid_date  loan_amount  risk_score  gender  \
# 0  bb08b55c1f   loan  2018-06-02         NaN         1900       0.133   Mujer
# 1  f23fd22961   paid  2018-06-01  2018-05-29         2400       0.941   Mujer
# 2  b723773be8   paid  2018-06-01  2018-05-21         1900       0.945   Mujer
# 3  726c7712e0   paid  2018-06-01  2018-04-02         2000       0.905   Mujer
# 4  8151753f45   paid  2018-06-01  2018-05-29         1600       0.908  Hombre
#
#    age  dependants   device urban_city loan_usage
# 0   33           0  android      rural      Otros
# 1   41           2      ios     urbano  Educacion
# 2   45           0      ios     urbano  Educacion
# 3   18           0      ios      rural  Educacion
# 4   18           0      ios     urbano  Educacion

# %%
data = credit.copy()
data.loc[data['device'] == 'android', 'device']  = 1
data.loc[data['device'] == 'ios', 'device']      = 0
data['device'] = data['device'].astype('int64')

data.loc[data['urban_city'] == 'rural', 'urban_city' ]  = 1
data.loc[data['urban_city'] == 'urbano', 'urban_city']  = 0
data['urban_city']= data['urban_city'].astype('int64')

data.loc[data['gender'] == 'Mujer', 'gender' ]  = 1
data.loc[data['gender'] == 'Hombre', 'gender']  = 0
data['gender'] = data['gender'].astype('int64')

data.head()
# Out:
#       loan_id status    due_date   paid_date  loan_amount  risk_score  gender  \
# 0  bb08b55c1f   loan  2018-06-02         NaN         1900       0.133       1
# 1  f23fd22961   paid  2018-06-01  2018-05-29         2400       0.941       1
# 2  b723773be8   paid  2018-06-01  2018-05-21         1900       0.945       1
# 3  726c7712e0   paid  2018-06-01  2018-04-02         2000       0.905       1
# 4  8151753f45   paid  2018-06-01  2018-05-29         1600       0.908       0
#
#    age  dependants  device  urban_city loan_usage
# 0   33           0       1           1      Otros
# 1   41           2       0           0  Educacion
# 2   45           0       0           0  Educacion
# 3   18           0       0           1  Educacion
# 4   18           0       0           0  Educacion

# %%
data.corr()
# Out:
#              loan_amount  risk_score    gender       age  dependants  \
# loan_amount     1.000000    0.016775  0.003718  0.013699    0.004704
# risk_score      0.016775    1.000000 -0.004565  0.061914    0.017301
# gender          0.003718   -0.004565  1.000000 -0.009588   -0.007185
# age             0.013699    0.061914 -0.009588  1.000000   -0.006916
# dependants      0.004704    0.017301 -0.007185 -0.006916    1.000000
# device          0.002458   -0.353939 -0.001797 -0.031628   -0.002294
# urban_city     -0.007089   -0.360980 -0.001503 -0.033014    0.003056
#
#                device  urban_city
# loan_amount  0.002458   -0.007089
# risk_score  -0.353939   -0.360980
# gender      -0.001797   -0.001503
# age         -0.031628   -0.033014
# dependants  -0.002294    0.003056
# device       1.000000    0.125948
# urban_city   0.125948    1.000000

# %%
def dfNorm(df):
    df_norm = (df - df.min()) / (df.max() - df.min())
    return df_norm

# %%
data['loan_amount'] = dfNorm(data['loan_amount'])

# %%
data['age'] = dfNorm(data['age'])

# %%
data['dependants'] = dfNorm(data['dependants'])

# %%
data.describe()
# Out:
#        loan_amount   risk_score       gender          age   dependants  \
# count  7924.000000  7924.000000  7924.000000  7924.000000  7924.000000
# mean      0.498291     0.853739     0.590232     0.441510     0.294043
# std       0.126032     0.121717     0.491822     0.323883     0.353881
# min       0.000000     0.103000     0.000000     0.000000     0.000000
# 25%       0.416667     0.769000     0.000000     0.131579     0.000000
# 50%       0.500000     0.889000     1.000000     0.447368     0.000000
# 75%       0.583333     0.954250     1.000000     0.717105     0.666667
# max       1.000000     0.999000     1.000000     1.000000     1.000000
#
#            device   urban_city
# count  7924.00000  7924.000000
# mean      0.15106     0.151186
# std       0.35813     0.358253
# min       0.00000     0.000000
# 25%       0.00000     0.000000
# 50%       0.00000     0.000000
# 75%       0.00000     0.000000
# max       1.00000     1.000000

# %%
data['loan_amount'].plot(kind = 'hist')

# %%
credit['loan_amount'].plot(kind = 'hist')

# %%
credit['loan_amount'].plot(kind = 'hist')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-3eb0f0ab532c> in <module>
# ----> 1 credit['loan_amount'].plot(kind = 'hist')
#
# ~/anaconda3/envs/bedu/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~/anaconda3/envs/bedu/lib/python3.6/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/anaconda3/envs/bedu/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     259     def generate(self):
#     260         self._args_adjust()
# --> 261         self._compute_plot_data()
#     262         self._setup_subplots()
#     263         self._make_plot()
#
# ~/anaconda3/envs/bedu/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     408         # no non-numeric frames or series allowed
#     409         if is_empty:
# --> 410             raise TypeError("no numeric data to plot")
#     411
#     412         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
def dfStd(df):
    df_std = (df - df.mean()) / (df.std())
    return df_std

# %%
std = dfStd(credit['loan_amount'])

# %% [markdown]
# El z-score también conocido como puntuación estándar, valores z, z-score, resultados normales, y las variables estandarizadas, el uso de "Z" se debe a la distribución normal es también conocida como la "distribución de Z", indica el número de estándar las desviaciones de una observación o dato está por encima o por debajo de la media

# %%
std.plot(kind='hist')

# %%
data.corr()
# Out:
#              loan_amount  risk_score    gender       age  dependants  \
# loan_amount     1.000000    0.016775  0.003718  0.013699    0.004704
# risk_score      0.016775    1.000000 -0.004565  0.061914    0.017301
# gender          0.003718   -0.004565  1.000000 -0.009588   -0.007185
# age             0.013699    0.061914 -0.009588  1.000000   -0.006916
# dependants      0.004704    0.017301 -0.007185 -0.006916    1.000000
# device          0.002458   -0.353939 -0.001797 -0.031628   -0.002294
# urban_city     -0.007089   -0.360980 -0.001503 -0.033014    0.003056
#
#                device  urban_city
# loan_amount  0.002458   -0.007089
# risk_score  -0.353939   -0.360980
# gender      -0.001797   -0.001503
# age         -0.031628   -0.033014
# dependants  -0.002294    0.003056
# device       1.000000    0.125948
# urban_city   0.125948    1.000000

# %%
lambda <arguments> : <Return Value if condition is True> if <condition> else <Return Value if condition is False>

# %%
def myFunc(x):
    if x < 1500:
        return 'Bajo'
    elif x>= 1500 and x < 2000 :
        return 'Medio'
    else:
        return 'Alto'

# %%
credit['categoria2'] = credit['loan_amount'].apply(myFunc)
credit['categoria2']
# Out:
# 0       Medio
# 1        Alto
# 2       Medio
# 3        Alto
# 4       Medio
#         ...
# 7919     Alto
# 7920     Alto
# 7921    Medio
# 7922     Alto
# 7923     Alto
# Name: categoria2, Length: 7924, dtype: object

# %%
credit['categoria'] = credit['loan_amount'].apply(lambda x: 'Bajo' 
                                                  if x < 1500 
                                                  else ('medio'if (x>= 1500 and  x < 2000 ) 
                                                        else 'Alto' ))
credit.groupby('categoria')['loan_amount'].describe()
# Out:
#             count         mean         std     min     25%     50%     75%  \
# categoria
# Alto       6910.0  2369.001447  246.509901  2000.0  2200.0  2300.0  2500.0
# Bajo         19.0  1310.526316   87.526103  1100.0  1300.0  1300.0  1400.0
# medio       995.0  1807.035176  108.727567  1500.0  1700.0  1800.0  1900.0
#
#               max
# categoria
# Alto       3500.0
# Bajo       1400.0
# medio      1900.0

# %%
credit.groupby(['categoria', 'due_date']).size()
# Out:
# categoria  due_date
# Alto       2018-06-01    3328
#            2018-06-02     705
#            2018-06-03     167
#            2018-06-04    1620
#            2018-06-05    1090
# Bajo       2018-06-01      12
#            2018-06-02       2
#            2018-06-04       5
# medio      2018-06-01     489
#            2018-06-02     109
#            2018-06-03      22
#            2018-06-04     235
#            2018-06-05     140
# dtype: int64

# %% [markdown]
# # Pivote

# %%
credit.head()
# Out:
#       loan_id status    due_date   paid_date  loan_amount  risk_score  gender  \
# 0  bb08b55c1f   loan  2018-06-02         NaN         1900       0.133   Mujer
# 1  f23fd22961   paid  2018-06-01  2018-05-29         2400       0.941   Mujer
# 2  b723773be8   paid  2018-06-01  2018-05-21         1900       0.945   Mujer
# 3  726c7712e0   paid  2018-06-01  2018-04-02         2000       0.905   Mujer
# 4  8151753f45   paid  2018-06-01  2018-05-29         1600       0.908  Hombre
#
#    age  dependants   device urban_city loan_usage categoria categoria2
# 0   33           0  android      rural      Otros     medio      Medio
# 1   41           2      ios     urbano  Educacion      Alto       Alto
# 2   45           0      ios     urbano  Educacion     medio      Medio
# 3   18           0      ios      rural  Educacion      Alto       Alto
# 4   18           0      ios     urbano  Educacion     medio      Medio

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-bc63b728e3b4> in <module>
# ----> 1 credit_pivot = credit.pivot(index='status',columns='gender', values='loan_amount')
#       2 credit_pivot
#
# ~/anaconda3/envs/bedu/lib/python3.6/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5921         from pandas.core.reshape.pivot import pivot
#    5922
# -> 5923         return pivot(self, index=index, columns=columns, values=values)
#    5924
#    5925     _shared_docs[
#
# ~/anaconda3/envs/bedu/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     448         else:
#     449             indexed = data._constructor_sliced(data[values].values, index=index)
# --> 450     return indexed.unstack(columns)
#     451
#     452
#
# ~/anaconda3/envs/bedu/lib/python3.6/site-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    3548         from pandas.core.reshape.reshape import unstack
#    3549
# -> 3550         return unstack(self, level, fill_value)
#    3551
#    3552     # ----------------------------------------------------------------------
#
# ~/anaconda3/envs/bedu/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     417             level=level,
#     418             fill_value=fill_value,
# --> 419             constructor=obj._constructor_expanddim,
#     420         )
#     421         return unstacker.get_result()
#
# ~/anaconda3/envs/bedu/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in __init__(self, values, index, level, value_columns, fill_value, constructor)
#     139
#     140         self._make_sorted_values_labels()
# --> 141         self._make_selectors()
#     142
#     143     def _make_sorted_values_labels(self):
#
# ~/anaconda3/envs/bedu/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     177
#     178         if mask.sum() < len(self.index):
# --> 179             raise ValueError("Index contains duplicate entries, cannot reshape")
#     180
#     181         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
credit.describe()
# Out:
#        loan_amount   risk_score          age   dependants
# count  7924.000000  7924.000000  7924.000000  7924.000000
# mean   2295.898536     0.853739    34.777385     0.882130
# std     302.477611     0.121717    12.307564     1.061643
# min    1100.000000     0.103000    18.000000     0.000000
# 25%    2100.000000     0.769000    23.000000     0.000000
# 50%    2300.000000     0.889000    35.000000     0.000000
# 75%    2500.000000     0.954250    45.250000     2.000000
# max    3500.000000     0.999000    56.000000     3.000000

# %%
credit.head()
# Out:
#       loan_id status    due_date   paid_date  loan_amount  risk_score  gender  \
# 0  bb08b55c1f   loan  2018-06-02         NaN         1900       0.133   Mujer
# 1  f23fd22961   paid  2018-06-01  2018-05-29         2400       0.941   Mujer
# 2  b723773be8   paid  2018-06-01  2018-05-21         1900       0.945   Mujer
# 3  726c7712e0   paid  2018-06-01  2018-04-02         2000       0.905   Mujer
# 4  8151753f45   paid  2018-06-01  2018-05-29         1600       0.908  Hombre
#
#    age  dependants   device urban_city loan_usage
# 0   33           0  android      rural      Otros
# 1   41           2      ios     urbano  Educacion
# 2   45           0      ios     urbano  Educacion
# 3   18           0      ios      rural  Educacion
# 4   18           0      ios     urbano  Educacion

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7924 entries, 0 to 7923
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   loan_id      7924 non-null   object
#  1   status       7924 non-null   object
#  2   due_date     7924 non-null   object
#  3   paid_date    6726 non-null   object
#  4   loan_amount  7924 non-null   int64
#  5   risk_score   7924 non-null   float64
#  6   gender       7924 non-null   object
#  7   age          7924 non-null   int64
#  8   dependants   7924 non-null   int64
#  9   device       7924 non-null   object
#  10  urban_city   7924 non-null   object
#  11  loan_usage   7924 non-null   object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 743.0+ KB

# %%
#Par

# %%
credit['paid_date'] = pd.to_datetime(credit.paid_date)
credit['due_date']  = pd.to_datetime(credit.due_date)
credit['DiasVencido'] = credit.paid_date - credit.due_date

credit['DiasVencido']
# Out:
# 0           NaT
# 1       -3 days
# 2      -11 days
# 3      -60 days
# 4       -3 days
#          ...
# 7919     2 days
# 7920    -1 days
# 7921     0 days
# 7922     8 days
# 7923     0 days
# Name: DiasVencido, Length: 7924, dtype: timedelta64[ns]

# %%
data = credit.dropna()
data.loc[data['DiasVencido'].astype('int64') >0, 'Llamar'] = 1 
llamar = data.dropna()

# %%
credit[credit.loan_id.isin(llamar.loan_id)]
# Out:
#          loan_id status   due_date  paid_date  loan_amount  risk_score  \
# 8     e40dc97aae   paid 2018-06-01 2018-06-18         3100       0.909
# 18    82cb85fcf9   paid 2018-06-04 2018-07-11         2400       0.915
# 45    3c4865d27d   paid 2018-06-01 2018-06-04         2400       0.621
# 46    4043398c88   paid 2018-06-02 2018-07-03         2400       0.547
# 50    71288fffd1   paid 2018-06-01 2018-06-07         2500       0.683
# ...          ...    ...        ...        ...          ...         ...
# 7905  c627715370   paid 2018-06-04 2018-06-05         2000       0.987
# 7906  a1e6b1d61b   paid 2018-06-05 2018-06-30         2400       0.850
# 7912  d5b570aaf4   paid 2018-06-05 2018-06-14         2300       0.843
# 7919  f530d011dd   paid 2018-06-05 2018-06-07         2900       0.972
# 7922  98b5f62c01   paid 2018-06-05 2018-06-13         2500       0.994
#
#       gender  age  dependants   device urban_city loan_usage DiasVencido
# 8     Hombre   18           0      ios      rural  Inversion     17 days
# 18     Mujer   18           1      ios     urbano   Personal     37 days
# 45     Mujer   21           3      ios      rural  Inversion      3 days
# 46    Hombre   47           0      ios     urbano      Otros     31 days
# 50     Mujer   53           0      ios     urbano      Otros      6 days
# ...      ...  ...         ...      ...        ...        ...         ...
# 7905  Hombre   18           0      ios     urbano  Inversion      1 days
# 7906   Mujer   50           0      ios     urbano  Inversion     25 days
# 7912   Mujer   43           0  android     urbano  Inversion      9 days
# 7919   Mujer   33           0      ios     urbano   Personal      2 days
# 7922   Mujer   48           0      ios     urbano  Educacion      8 days
#
# [1031 rows x 13 columns]

# %%
by_date =  credit.groupby('due_date').count()
by_date =  by_date.reset_index()
by_date.plot(x='due_date',y='loan_id' ,kind='line',
             label='# créditos',
             title='créditos a vencen en los próximos 5 días')

# %%
credit.groupby('due_date').count()
# Out:
#             loan_id  status  paid_date  loan_amount  risk_score  gender   age  \
# due_date
# 2018-06-01     3829    3829       3308         3829        3829    3829  3829
# 2018-06-02      816     816        661          816         816     816   816
# 2018-06-03      189     189        134          189         189     189   189
# 2018-06-04     1860    1860       1590         1860        1860    1860  1860
# 2018-06-05     1230    1230       1033         1230        1230    1230  1230
#
#             dependants  device  urban_city  loan_usage  DiasVencido
# due_date
# 2018-06-01        3829    3829        3829        3829         3308
# 2018-06-02         816     816         816         816          661
# 2018-06-03         189     189         189         189          134
# 2018-06-04        1860    1860        1860        1860         1590
# 2018-06-05        1230    1230        1230        1230         1033
